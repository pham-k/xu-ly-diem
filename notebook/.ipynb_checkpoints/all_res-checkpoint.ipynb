# %%
import pandas as pd
import util
import mark_helper as mh

# %%
# PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-DD-1-THILT1 (Responses).xlsx'
# PATH_RCC1 = '../data/2021/response/STAT1001-2021-KX-2-CC1 (Responses).xlsx'
# util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
# util.parse_response(PATH_RCC1)

# %%
PATH_CUTPOINT = '../data/2021/reference/cutpoint.csv'
cutpoint = pd.read_csv(PATH_CUTPOINT, index_col=None)

# %%
PATH_RCC1 = '../data/2021/response/STAT1001-2021-KX-2-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/STAT1001-2021-KX-2-CC2 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1001-2021-KX-2-QT1 (Responses).xlsx'
PATH_RTHI1 = '../data/2021/response/STAT1001-2021-KX-2-THI1 (Responses).xlsx'
PATH_RTHI2 = '../data/2021/response/STAT1001-2021-KX-2-THI2 (Responses).xlsx'


rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rqt1 = util.parse_response(PATH_RQT1)
rthi1 = util.parse_response(PATH_RTHI1, regex_user_id=None, regex_year=None)
rthi2 = util.parse_response(PATH_RTHI2)

#fix
rcc2.loc[rcc2.user_id == '20568990040' , 'user_id'] = '2056990040'  # Sai MSSV
rcc1.loc[rcc1.user_id == '2056990029' , 'class_id'] = 'KX-2020'  # Sai lop
rcc1.loc[rcc1.user_id == '1853010033' , 'class_id'] = 'DD-2018'  # Sai lop
rcc2.loc[rcc2.user_id == '1853010033' , 'class_id'] = 'DD-2018'  # Sai lop
rqt1.loc[rqt1.user_id == '1853010033' , 'class_id'] = 'DD-2018'  # Sai lop
rthi2.loc[rthi2.user_id == '1853010033' , 'class_id'] = 'DD-2018'  # Sai lop
rthi2['score'] = rthi2['score'] + 2  # De thi: Cau 3, 9 phan 1.1 khong chinh xac

rcc1['course_id'] = 'STAT1001-2021-KX-2'
rcc2['course_id'] = 'STAT1001-2021-KX-2'
rqt1['course_id'] = 'STAT1001-2021-KX-2'
rthi1['course_id'] = 'STAT1001-2021-KX-2'
rthi2['course_id'] = 'STAT1001-2021-KX-2'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='STAT1001-2021-KX-2-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=20, exam_id='STAT1001-2021-KX-2-CC2')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1001-2021-KX-2-QT1')
thi1 = mh.get_mark(rthi1, cutpoint, total=50, exam_id='STAT1001-2021-KX-2-THI1')
thi2 = mh.get_mark(rthi2, cutpoint, total=50, exam_id='STAT1001-2021-KX-2-THI2')

res = (
    cc1
    .append(cc2)
    .append(qt1)
    .append(thi1)
    .append(thi2)
)
# Out:
# /tmp/ipykernel_4682/2605046542.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/2605046542.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/2605046542.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thi1)
# /tmp/ipykernel_4682/2605046542.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thi2)

# %%
# res.query('exam_id == "STAT1001-2021-KX-2-THI2"')
# res.query('user_id == "1853010100"')
# rthi2.info()

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-DD-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-DD-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-DD-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-DD-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-DD-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-DD-1-THITH1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
rthith1 = util.parse_response(PATH_RTHITH1, regex_user_id=None, regex_year=None)

# Fix
rcc3.loc[rcc3.user_id == '215301014', 'user_id'] = '2153010134'  # nguyen trieu hai tran, sai mssv
rcc3.loc[rcc3.user_id == '215301001', 'user_id'] = '2153010001'  # vu ngoc phuong an, sai mssv
rcc1.loc[rcc1.user_id == '2153030069', 'user_id'] = '2153010069'  # nguyen thi my, sai mssv
rcc1.loc[rcc1.user_id == '2153010068', 'class_id'] = 'DD-2021'  # nguyen thi my, sai lop
rcc1.loc[rcc1.user_id == '2053010043', 'class_id'] = 'DD-2020'  # tran thi lan huong, sai lop
rcc2.loc[rcc2.user_id == '2053010043', 'class_id'] = 'DD-2020'  # tran thi lan huong, sai lop
rcc3.loc[rcc3.user_id == '2053010043', 'class_id'] = 'DD-2020'  # tran thi lan huong, sai lop
rqt1.loc[rqt1.user_id == '2053010043', 'class_id'] = 'DD-2020'  # tran thi lan huong, sai lop
rthilt1.loc[rthilt1.user_id == '2053010043', 'class_id'] = 'DD-2020'  # tran thi lan huong, sai lop
rthith1.loc[rthith1.user_id == '2053010043', 'class_id'] = 'DD-2020'  # tran thi lan huong, sai lop
rthilt1.loc[rthilt1.user_id == '215301011', 'user_id'] = '2153010111'  # nguyen thu thao, sai mssv
rthilt1.loc[rthilt1.user_id == '215301043', 'user_id'] = '2153010043'  # do thu huong, sai mssv
rthith1.loc[rthith1.user_id == '253010053', 'user_id'] = '2153010053'  # tran anh khoa, sai mssv
rthilt1.loc[rthilt1.user_id == '215301083', 'user_id'] = '2153010183'  # huynh thi anh ngoc, sai mssv
rthilt1.loc[rthilt1.user_id == '1853010095@pnt.edu.vn', 'user_id'] = '1853010095'  # nguyen thanh thao, sai mssv
rcc1.loc[rcc1.user_id == '2053010057', 'class_id'] = 'DD-2020'  # huynh thi my linh, sai lop
rcc2.loc[rcc2.user_id == '2053010057', 'class_id'] = 'DD-2020'  # huynh thi my linh, sai lop
rcc3.loc[rcc3.user_id == '2053010057', 'class_id'] = 'DD-2020'  # huynh thi my linh, sai lop
rqt1.loc[rqt1.user_id == '2053010057', 'class_id'] = 'DD-2020'  # huynh thi my linh, sai lop
rcc1.loc[rcc1.user_id == '2053010158', 'class_id'] = 'DD-2020'  # sai lop
rcc2.loc[rcc2.user_id == '2053010158', 'class_id'] = 'DD-2020'  # sai lop
rcc3.loc[rcc3.user_id == '2053010158', 'class_id'] = 'DD-2020'  # sai lop
rqt1.loc[rqt1.user_id == '2053010158', 'class_id'] = 'DD-2020'  # sai lop

rcc1['course_id'] = 'INFO1001-2021-DD-1'
rcc2['course_id'] = 'INFO1001-2021-DD-1'
rcc3['course_id'] = 'INFO1001-2021-DD-1'
rqt1['course_id'] = 'INFO1001-2021-DD-1'
rthilt1['course_id'] = 'INFO1001-2021-DD-1'
rthith1['course_id'] = 'INFO1001-2021-DD-1'


cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-DD-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-DD-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-DD-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-DD-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-DD-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-DD-1-THITH1')

# SV co diem danh, k co bai --> 0 diem
thith1 = mh.set_score(
    ['2153010074', 'DD-2021', 'INFO1001-2021-DD-1', 'INFO1001-2021-DD-1-THITH1', 0], thith1)
thilt1 = mh.set_score(
    ['2153010114', 'DD-2021', 'INFO1001-2021-DD-1', 'INFO1001-2021-DD-1-THILT1', 0], thilt1)
thith1 = mh.set_score(
    ['2153010115', 'DD-2021', 'INFO1001-2021-DD-1', 'INFO1001-2021-DD-1-THITH1', 0], thith1)

res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1))
# Out:
# /tmp/ipykernel_4682/1219854887.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/1219854887.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/1219854887.py:67: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/1219854887.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/1219854887.py:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
# res[res.user_id == '2053010043']

# rthilt1 = util.parse_response(PATH_RTHILT1)

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-DHD-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-DHD-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-DHD-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-DHD-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-DHD-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-DHD-1-THITH1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
rthith1 = util.parse_response(PATH_RTHITH1, regex_user_id=None, regex_year=None)

# Fix
rcc2.loc[rcc2.user_id == '1154010071', 'user_id'] = '2154010071' # mai ai thi, sai mssv
rcc3.loc[rcc3.user_id == '1854010060', 'class_id'] = 'DHD-2018'  # dao uyen tran, sai lop
rthith1.loc[rthith1.user_id == '21541010013', 'user_id'] = '2154010013'  # hoang le ngoc han, sai mssv
rthith1.loc[rthith1.user_id == '254010023', 'user_id'] = '2154010023'  # luong bao lien, sai mssv
rthilt1.loc[rthilt1.user_id == '21554010069', 'user_id'] = '2154010069'  # ly tam xuyen, sai mssv


rcc1['course_id'] = 'INFO1001-2021-DHD-1'
rcc2['course_id'] = 'INFO1001-2021-DHD-1'
rcc3['course_id'] = 'INFO1001-2021-DHD-1'
rqt1['course_id'] = 'INFO1001-2021-DHD-1'
rthilt1['course_id'] = 'INFO1001-2021-DHD-1'
rthith1['course_id'] = 'INFO1001-2021-DHD-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-DHD-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-DHD-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-DHD-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-DHD-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-DHD-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-DHD-1-THITH1')

# SV co diem danh, k co bai --> 0 diem
thith1 = mh.set_score(
    ['2154010027', 'DHD-2021', 'INFO1001-2021-DHD-1', 'INFO1001-2021-DHD-1-THITH1', 0], thith1)

res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1))
# Out:
# /tmp/ipykernel_4682/4016454487.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/4016454487.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/4016454487.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/4016454487.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/4016454487.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
# res.query('user_id == "2154010027"')

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-KT-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-KT-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-KT-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-KT-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-KT-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-KT-1-THITH1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
rthith1 = util.parse_response(PATH_RTHITH1, regex_user_id=None, regex_year=None)

#fix
rcc1.loc[rcc1.user_id == '21562020008', 'user_id'] = '2156020008'  # huynh thanh hien, sai mssv


rcc1['course_id'] = 'INFO1001-2021-KT-1'
rcc2['course_id'] = 'INFO1001-2021-KT-1'
rcc3['course_id'] = 'INFO1001-2021-KT-1'
rqt1['course_id'] = 'INFO1001-2021-KT-1'
rthilt1['course_id'] = 'INFO1001-2021-KT-1'
rthith1['course_id'] = 'INFO1001-2021-KT-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-KT-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-KT-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-KT-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-KT-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-KT-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-KT-1-THITH1')

# SV co diem danh, k co bai --> 0 diem
thith1 = mh.set_score(
    ['2156020021', 'KT-2021', 'INFO1001-2021-KT-1', 'INFO1001-2021-KT-1-THITH1', 0], thith1)
thith1 = mh.set_score(
    ['2156020037', 'KT-2021', 'INFO1001-2021-KT-1', 'INFO1001-2021-KT-1-THITH1', 0], thith1)

res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1))
# Out:
# /tmp/ipykernel_4682/504764871.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/504764871.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/504764871.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/504764871.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/504764871.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
# res.query('user_id == "2156020021"')

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-KX-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-KX-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-KX-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-KX-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-KX-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-KX-1-THITH1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
rthith1 = util.parse_response(PATH_RTHITH1, regex_user_id=None, regex_year=None)

rcc3.loc[rcc3.user_id == '2156880014', 'user_id'] = '2156990014' # nguyen luu hoang bao ngan, sai mssv

rcc1['course_id'] = 'INFO1001-2021-KX-1'
rcc2['course_id'] = 'INFO1001-2021-KX-1'
rcc3['course_id'] = 'INFO1001-2021-KX-1'
rqt1['course_id'] = 'INFO1001-2021-KX-1'
rthilt1['course_id'] = 'INFO1001-2021-KX-1'
rthith1['course_id'] = 'INFO1001-2021-KX-1'
rthilt1.loc[rthilt1.user_id == '2056020028', 'course_id'] = 'INFO1001-2021-KT-1'  # do thi chung voi kx
rthith1.loc[rthith1.user_id == '2056020028', 'course_id'] = 'INFO1001-2021-KT-1'  # do thi chung voi kx

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-KX-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-KX-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-KX-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-KX-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-KX-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-KX-1-THITH1')
thilt1.loc[thilt1.user_id == '2056020028', 'exam_id'] = 'INFO1001-2021-KT-1-THILT1'  # do thi chung voi kx
thith1.loc[thith1.user_id == '2056020028', 'exam_id'] = 'INFO1001-2021-KT-1-THITH1'  # do thi chung voi kx


res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1))
# Out:
# /tmp/ipykernel_4682/3474469428.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/3474469428.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/3474469428.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/3474469428.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/3474469428.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
# rthilt1.loc[rthilt1.user_id == '2056020028', 'course_id'] = 'INFO1001-2021-KT-1'
# res.query('user_id == "2056020028"')

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-XN-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-XN-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-XN-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-XN-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-XN-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-XN-1-THITH1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
rthith1 = util.parse_response(PATH_RTHITH1, regex_user_id=None, regex_year=None)

rthith1.loc[rthith1.user_id == '21156010062', 'user_id'] = '2156010062' # nguyen minh phuong, sai mssv


rcc1['course_id'] = 'INFO1001-2021-XN-1'
rcc2['course_id'] = 'INFO1001-2021-XN-1'
rcc3['course_id'] = 'INFO1001-2021-XN-1'
rqt1['course_id'] = 'INFO1001-2021-XN-1'
rthilt1['course_id'] = 'INFO1001-2021-XN-1'
rthith1['course_id'] = 'INFO1001-2021-XN-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-XN-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-XN-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-XN-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-XN-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-XN-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-XN-1-THITH1')

res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1))
# Out:
# /tmp/ipykernel_4682/1641493376.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/1641493376.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/1641493376.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/1641493376.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/1641493376.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-YT-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-YT-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-YT-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-YT-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-YT-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-YT-1-THITH1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1, regex_user_id=None, regex_year=None)
rthith1 = util.parse_response(PATH_RTHITH1, regex_user_id=None, regex_year=None)

#Fix
rcc3.loc[rcc3.user_id == '215710004', 'user_id'] = '2157010004' # trieu thi hoang bich, sai mssv
rcc1.loc[rcc1.user_id == '215710019', 'user_id'] = '2157010019' # pham dang khoa, sai mssv
rcc2.loc[rcc2.user_id == '215710019', 'user_id'] = '2157010019' # pham dang khoa, sai mssv
rcc3.loc[rcc3.user_id == '215710019', 'user_id'] = '2157010019' # pham dang khoa, sai mssv
rcc1.loc[rcc1.user_id == '21570100882', 'user_id'] = '2157010082' # nguyen nhat thanh, sai mssv
rthilt1.loc[rthilt1.user_id == '2157010019@pnt.edu.vn', 'user_id'] = '2157010019' # pham dang khoa, sai mssv
rthilt1.loc[rthilt1.user_id == '215700030', 'user_id'] = '2157010030' # duong chi nam, sai mssv
rthith1.loc[rthith1.user_id == '215701001', 'user_id'] = '2157010013' # nguyen trung hieu, sai mssv
rthith1.loc[rthith1.user_id == '2157010033@pnt.edu.vn', 'user_id'] = '2157010033' # du my ngoc, sai mssv
rthith1.loc[rthith1.user_id == 'Hồ Thị Quỳnh Nhi', 'user_id'] = '2157010036' # ho thi quynh nhi, sai mssv



rcc1['course_id'] = 'INFO1001-2021-YT-1'
rcc2['course_id'] = 'INFO1001-2021-YT-1'
rcc3['course_id'] = 'INFO1001-2021-YT-1'
rqt1['course_id'] = 'INFO1001-2021-YT-1'
rthilt1['course_id'] = 'INFO1001-2021-YT-1'
rthith1['course_id'] = 'INFO1001-2021-YT-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-YT-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-YT-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-YT-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-YT-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-YT-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-YT-1-THITH1')

# SV co diem danh, k co bai --> 0 diem
thith1 = mh.set_score(
    ['2157010055', 'YT-2021', 'INFO1001-2021-YT-1', 'INFO1001-2021-YT-1-THITH1', 0], thith1)

res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1))
# Out:
# /tmp/ipykernel_4682/2683310215.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/2683310215.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/2683310215.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/2683310215.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/2683310215.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
# res.query('user_id == "2157010055"')

# %%
PATH_RTHILT2 = '../data/2021/response/INFO1001-2021-CN-1-THILT2 (Responses).xlsx'
PATH_RTHITH2 = '../data/2021/response/INFO1001-2021-CN-1-THITH2 (Responses).xlsx'
rthilt2 = util.parse_response(PATH_RTHILT2, regex_user_id=None, regex_year=None)
rthith2 = util.parse_response(PATH_RTHITH2, regex_user_id=None, regex_year=None)

rthilt2_kx = rthilt2.query('class_id == "KX-2021"')
rthilt2_kx['course_id'] = 'INFO1001-2021-KX-1'
thilt2_kx = mh.get_mark(rthilt2_kx, cutpoint, total=50, exam_id='INFO1001-2021-KX-1-THILT2')

rthith2_kx = rthith2.query('class_id == "KX-2021"')
rthith2_kx['course_id'] = 'INFO1001-2021-KX-1'
thith2_kx = mh.get_mark(rthith2_kx, cutpoint, total=25, exam_id='INFO1001-2021-KX-1-THITH2')


rthilt2_dd = rthilt2.query('class_id == "DD-2021"')
rthilt2_dd['course_id'] = 'INFO1001-2021-DD-1'
thilt2_dd = mh.get_mark(rthilt2_dd, cutpoint, total=50, exam_id='INFO1001-2021-DD-1-THILT2')

rthith2_dd = rthith2.query('class_id == "DD-2021"')
rthith2_dd['course_id'] = 'INFO1001-2021-DD-1'
thith2_dd = mh.get_mark(rthith2_dd, cutpoint, total=25, exam_id='INFO1001-2021-DD-1-THITH2')

rthilt2_dd2 = rthilt2.query('class_id == "DD-2020"')
rthilt2_dd2['course_id'] = 'INFO1001-2021-DD-1'
thilt2_dd2 = mh.get_mark(rthilt2_dd2, cutpoint, total=50, exam_id='INFO1001-2021-DD-1-THILT2')

rthith2_dd2 = rthith2.query('class_id == "DD-2020"')
rthith2_dd2['course_id'] = 'INFO1001-2021-DD-1'
thith2_dd2 = mh.get_mark(rthith2_dd2, cutpoint, total=25, exam_id='INFO1001-2021-DD-1-THITH2')

rthilt2_dd4 = rthilt2.query('class_id == "DD-2018"')
rthilt2_dd4['course_id'] = 'INFO1001-2021-DD-1'
thilt2_dd4 = mh.get_mark(rthilt2_dd4, cutpoint, total=50, exam_id='INFO1001-2021-DD-1-THILT2')

rthith2_dd4 = rthith2.query('class_id == "DD-2018"')
rthith2_dd4['course_id'] = 'INFO1001-2021-DD-1'
thith2_dd4 = mh.get_mark(rthith2_dd4, cutpoint, total=25, exam_id='INFO1001-2021-DD-1-THITH2')


rthilt2_dhd = rthilt2.query('class_id == "DHD-2021"')
rthilt2_dhd['course_id'] = 'INFO1001-2021-DHD-1'
thilt2_dhd = mh.get_mark(rthilt2_dhd, cutpoint, total=50, exam_id='INFO1001-2021-DHD-1-THILT2')

rthith2_dhd = rthith2.query('class_id == "DHD-2021"')
rthith2_dhd['course_id'] = 'INFO1001-2021-DHD-1'
thith2_dhd = mh.get_mark(rthith2_dhd, cutpoint, total=25, exam_id='INFO1001-2021-DHD-1-THITH2')

rthilt2_kt = rthilt2.query('class_id == "KT-2021"')
rthilt2_kt['course_id'] = 'INFO1001-2021-KT-1'
thilt2_kt = mh.get_mark(rthilt2_kt, cutpoint, total=50, exam_id='INFO1001-2021-KT-1-THILT2')

rthith2_kt = rthith2.query('class_id == "KT-2021"')
rthith2_kt['course_id'] = 'INFO1001-2021-KT-1'
thith2_kt = mh.get_mark(rthith2_kt, cutpoint, total=25, exam_id='INFO1001-2021-KT-1-THITH2')

rthilt2_yt = rthilt2.query('class_id == "YT-2021"')
rthilt2_yt['course_id'] = 'INFO1001-2021-YT-1'
thilt2_yt = mh.get_mark(rthilt2_yt, cutpoint, total=50, exam_id='INFO1001-2021-YT-1-THILT2')

rthith2_yt = rthith2.query('class_id == "YT-2021"')
rthith2_yt['course_id'] = 'INFO1001-2021-YT-1'
thith2_yt = mh.get_mark(rthith2_yt, cutpoint, total=25, exam_id='INFO1001-2021-YT-1-THITH2')

rthilt2_yt2 = rthilt2.query('class_id == "YT-2020"')
rthilt2_yt2['course_id'] = 'INFO1001-2021-YT-1'
thilt2_yt2 = mh.get_mark(rthilt2_yt2, cutpoint, total=50, exam_id='INFO1001-2021-YT-1-THILT2')

rthith2_yt2 = rthith2.query('class_id == "YT-2020"')
rthith2_yt2['course_id'] = 'INFO1001-2021-YT-1'
thith2_yt2 = mh.get_mark(rthith2_yt2, cutpoint, total=25, exam_id='INFO1001-2021-YT-1-THITH2')

rthilt2_yt3 = rthilt2.query('class_id == "YT-2019"')
rthilt2_yt3['course_id'] = 'INFO1001-2021-YT-1'
thilt2_yt3 = mh.get_mark(rthilt2_yt3, cutpoint, total=50, exam_id='INFO1001-2021-YT-1-THILT2')

rthith2_yt3 = rthith2.query('class_id == "YT-2019"')
rthith2_yt3['course_id'] = 'INFO1001-2021-YT-1'
thith2_yt3 = mh.get_mark(rthith2_yt3, cutpoint, total=25, exam_id='INFO1001-2021-YT-1-THITH2')

rthilt2_xn = rthilt2.query('class_id == "XN-2021"')
rthilt2_xn['course_id'] = 'INFO1001-2021-XN-1'
thilt2_xn = mh.get_mark(rthilt2_xn, cutpoint, total=50, exam_id='INFO1001-2021-XN-1-THILT2')

rthith2_xn = rthith2.query('class_id == "XN-2021"')
rthith2_xn['course_id'] = 'INFO1001-2021-XN-1'
thith2_xn = mh.get_mark(rthith2_xn, cutpoint, total=25, exam_id='INFO1001-2021-XN-1-THITH2')

res = (
    res
    .append(thilt2_dd)
    .append(thith2_dd)
    .append(thilt2_dd2)
    .append(thith2_dd2)
    .append(thilt2_dd4)
    .append(thith2_dd4)
    .append(thilt2_dhd)
    .append(thith2_dhd)
    .append(thilt2_kt)
    .append(thith2_kt)
    .append(thilt2_kx)
    .append(thith2_kx)
    .append(thilt2_xn)
    .append(thith2_xn)
    .append(thilt2_yt)
    .append(thith2_yt)
    .append(thilt2_yt2)
    .append(thith2_yt2)
    .append(thilt2_yt3)
    .append(thith2_yt3)
)
# Out:
# /tmp/ipykernel_4682/333275307.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rthith2_kx['course_id'] = 'INFO1001-2021-KX-1'
# /home/phamk/Documents/project/xu-ly-diem/notebook/mark_helper.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_score'] = df['score'] / total
# /home/phamk/Documents/project/xu-ly-diem/notebook/mark_helper.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
PATH_RCC1 = '../data/2021/response/STAT1003-2021-KX-3-CC1 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1003-2021-KX-3-QT1 (Responses).xlsx'
PATH_RTHI1 = '../data/2021/response/STAT1003-2021-KX-3-THI1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rqt1 = util.parse_response(PATH_RQT1)
rthi1 = util.parse_response(PATH_RTHI1)

#fix
rcc1.loc[rcc1.user_id == '195699021', 'user_id'] = '1956990021' # van thi doan trinh, sai mssv

rcc1['course_id'] = 'STAT1003-2021-KX-3'
rqt1['course_id'] = 'STAT1003-2021-KX-3'
rthi1['course_id'] = 'STAT1003-2021-KX-3'

cc1 = mh.get_mark(rcc1, cutpoint, total=25, exam_id='STAT1003-2021-KX-3-CC1')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1003-2021-KX-3-QT1')
thi1 = mh.get_mark(rthi1, cutpoint, total=50, exam_id='STAT1003-2021-KX-3-THI1')

res = (
    res
    .append(cc1)
    .append(qt1)
    .append(thi1)
)
# Out:
# /tmp/ipykernel_4682/2732710828.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/2732710828.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/2732710828.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thi1)

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-YRD-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-YRD-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-YRD-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-YRD-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-YRD-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-YRD-1-THITH1 (Responses).xlsx'
PATH_RTHILT2 = '../data/2021/response/INFO1001-2021-YRD-1-THILT2 (Responses).xlsx'
PATH_RTHITH2 = '../data/2021/response/INFO1001-2021-YRD-1-THITH2 (Responses).xlsx'
PATH_RTHITH2_1 = '../data/2021/response/INFO1001-2021-YRD-1-THITH2-1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1)
rthith1 = util.parse_response(PATH_RTHITH1)
rthilt2 = util.parse_response(PATH_RTHILT2)
rthith2 = util.parse_response(PATH_RTHITH2)

rthith2_1 = util.parse_response(PATH_RTHITH2_1)

# Fix
rcc3.loc[rcc3.user_id == '2151050059', 'user_id'] = '2151010059'  # nguyen ngoc chuong, sai mssv
rcc1.loc[rcc1.user_id == '2101510281', 'user_id'] = '2151010281'  # huynh thi diu linh, sai mssv
rcc1.loc[rcc1.user_id == '1951010821', 'class_id'] = 'YA-2019'  # phan duy tan , sai ma lop
rcc2.loc[rcc2.user_id == '1951010821', 'class_id'] = 'YA-2019'  # phan duy tan , sai ma lop
rcc2.loc[rcc2.user_id == '2152010622', 'user_id'] = '2151010622'  # nguyen thi my tuyet, sai mssv
rcc2.loc[rcc2.user_id == '215010214', 'user_id'] = '2151010214'  # nguyen doan gia huynh, sai mssv
rcc2.loc[rcc2.name == 'LÊ THANH SANG', 'user_id'] = '2151010472'  # le thanh sang, sai mssv
rcc2.loc[rcc2.user_id == '21510105000', 'user_id'] = '2151010500'  # ngo duc thanh, sai mssv
rcc3.loc[rcc3.user_id == '2151010348', 'class_id'] = 'YD-2021'  # nguyen hong ngoc, sai ma lop
rcc3.loc[rcc3.user_id == '2151010579', 'class_id'] = 'YD-2021'  # ma thien trang, sai ma lop
rthilt1.loc[rthilt1.user_id == '2151010072@pnt', 'user_id'] = '2151010072'  # cu huy dat, sai mssv
rthilt1.loc[rthilt1.user_id == '2151010554@pnt', 'user_id'] = '2151010554'  # nguyen ngoc khanh thy, sai mssv
rthilt1.loc[rthilt1.user_id == '2151010472@pnt', 'user_id'] = '2151010472'  # le thanh sang, sai mssv
rthilt1.loc[rthilt1.user_id == '21510101486', 'user_id'] = '2151010486'  # tran gia tan, sai mssv
rthilt1.loc[rthilt1.user_id == '215100348', 'user_id'] = '2151010348'  # nguyen hong ngoc, sai mssv

rthith1.loc[rthith1.user_id == '2151010542@pnt', 'user_id'] = '2151010542'  # nguyen vo hoang thuan, sai mssv
rthith1.loc[rthith1.user_id == '21451010463', 'user_id'] = '2151010463'  # le truc quynh, sai mssv
rthith1.loc[rthith1.user_id == '21551010507', 'user_id'] = '2151010507'  # ngo van thi, sai mssv
rthith1.loc[rthith1.user_id == '21552010010', 'user_id'] = '2152010010'  # huynh duy dat, sai mssv

rthilt1.loc[rthilt1.user_id == '2151010706', 'score'] = 0  # manith sonelasith, vi pham quy che thi
rthilt1.loc[rthilt1.user_id == '2151010706', 'pct_score'] = 0  # manith sonelasith, vi pham quy che thi
rthith1.loc[rthith1.user_id == '2151010706', 'score'] = 0  # manith sonelasith, vi pham quy che thi
rthith1.loc[rthith1.user_id == '2151010706', 'pct_score'] = 0  # manith sonelasith, vi pham quy che thi

rcc1['course_id'] = 'INFO1001-2021-YRD-1'
rcc2['course_id'] = 'INFO1001-2021-YRD-1'
rcc3['course_id'] = 'INFO1001-2021-YRD-1'
rqt1['course_id'] = 'INFO1001-2021-YRD-1'
rthilt1['course_id'] = 'INFO1001-2021-YRD-1'
rthith1['course_id'] = 'INFO1001-2021-YRD-1'
rthith2_1['course_id'] = 'INFO1001-2021-YRD-1'
rthilt2['course_id'] = 'INFO1001-2021-YRD-1'
rthith2['course_id'] = 'INFO1001-2021-YRD-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-YRD-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-YRD-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-YRD-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-YRD-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-YRD-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-YRD-1-THITH1')
thith2_1 = mh.get_mark(rthith2_1, cutpoint, total=25, exam_id='INFO1001-2021-YRD-1-THITH2')
thilt2 = mh.get_mark(rthilt2, cutpoint, total=50, exam_id='INFO1001-2021-YRD-1-THILT2')
thith2 = mh.get_mark(rthith2, cutpoint, total=25, exam_id='INFO1001-2021-YRD-1-THITH2')

# SV co diem danh, k co bai --> 0 diem

res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1)
    .append(thith2_1)
    .append(thilt2)
    .append(thith2)
)

# SV thi lai cua nam 2020, lay diem lan 2 nam 2020

res.loc[res.user_id == '2055010028', 'course_id'] = 'INFO1001-2020-YRD-1'
res.loc[res.user_id == '2055010028', 'exam_id'] = 'INFO1001-2020-YRD-1-THITH1'
# Out:
# /tmp/ipykernel_4682/1582883551.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/1582883551.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/1582883551.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/1582883551.py:76: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/1582883551.py:77: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
PATH_RCC1 = '../data/2021/response/STAT1002-2021-YRD-1-CC1 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1002-2021-YRD-1-QT1 (Responses).xlsx'
PATH_RTHI1 = '../data/2021/response/STAT1002-2021-YRD-1-THI1 (Responses).xlsx'
PATH_RTHI2 = '../data/2021/response/STAT1002-2021-YRD-1-THI2 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rqt1 = util.parse_response(PATH_RQT1)
rthi1 = util.parse_response(PATH_RTHI1)
rthi2 = util.parse_response(PATH_RTHI2)

# Fix
rqt1.loc[rqt1.name == "TRẦN ÁNH NGỌC", 'user_id'] = '2151010350'  # tran anh ngoc, sai mssv
rqt1.loc[rqt1.user_id == '2151010472@pnt', 'user_id'] = '2151010472'  # le thanh sang, sai mssv
rqt1.loc[rqt1.user_id == '2151010037@pnt', 'user_id'] = '2151010037'  # nguyen thai bao, sai mssv
rqt1.loc[rqt1.user_id == '2151010528@pnt', 'user_id'] = '2151010528'  # nguyen thai bao, sai mssv
rcc1.loc[rcc1.user_id == '2151010285@pnt', 'user_id'] = '2151010285'  # nguyen phuong hong linh, sai mssv
rcc1.loc[rcc1.user_id == '2151010472@pnt', 'user_id'] = '2151010472'  # le thanh sang, sai mssv
rcc1.loc[rcc1.user_id == '2152010080', 'class_id'] = 'DUOC-2021'  # nguyen pham thuy tien, sai lop
rcc1.loc[rcc1.user_id == '1751010986', 'class_id'] = ''  # INTHATHILATH XAIYA, sai lop
rcc1.loc[rcc1.user_id == '21551010440', 'user_id'] = '2151010440'  # le vo anh quan, sai mssv
rthi1.loc[rthi1.name == 'NGÔ NGỌC CHÂU', 'user_id'] = '2151010054'  # ngo ngoc chau, sai mssv


rcc1['course_id'] = 'STAT1002-2021-YRD-1'
rqt1['course_id'] = 'STAT1002-2021-YRD-1'
rthi1['course_id'] = 'STAT1002-2021-YRD-1'
rthi2['course_id'] = 'STAT1002-2021-YRD-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=25, exam_id='STAT1002-2021-YRD-1-CC1')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1002-2021-YRD-1-QT1')
thi1 = mh.get_mark(rthi1, cutpoint, total=50, exam_id='STAT1002-2021-YRD-1-THI1')
thi2 = mh.get_mark(rthi2, cutpoint, total=50, exam_id='STAT1002-2021-YRD-1-THI2')

res = (
    res
    .append(cc1)
    .append(qt1)
    .append(thi1)
    .append(thi2)
)

# rthi1.query('name == "NGÔ NGỌC CHÂU"')
# Out:
# /tmp/ipykernel_4682/1098634539.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/1098634539.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/1098634539.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thi1)
# /tmp/ipykernel_4682/1098634539.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thi2)

# %%
PATH_RCC1 = '../data/2021/response/STAT1001-2021-KT-2-CC1 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1001-2021-KT-2-QT1 (Responses).xlsx'
PATH_MTHI1 = '../data/2021/response/mark-STAT1001-2021-KT-2-THI1.csv'

rcc1 = util.parse_response(PATH_RCC1)
rqt1 = util.parse_response(PATH_RQT1)
# rthi1 = util.parse_response(PATH_RTHI1)


#fix


rcc1['course_id'] = 'STAT1001-2021-KT-2'
rqt1['course_id'] = 'STAT1001-2021-KT-2'
# rthi1['course_id'] = 'STAT1001-2021-KT-2'


cc1 = mh.get_mark(rcc1, cutpoint, total=35, exam_id='STAT1001-2021-KT-2-CC1')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1001-2021-KT-2-QT1')
# thi1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='STAT1001-2021-KT-2-THI1')
thi1 = pd.read_csv(PATH_MTHI1, dtype={'user_id': 'str'})

res = (
    res
    .append(cc1)
    .append(qt1)
    .append(thi1)
    )
# thi1.info()
# Out:
# /tmp/ipykernel_4682/135885542.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/135885542.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/135885542.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thi1)

# %%
PATH_RCC1 = '../data/2021/response/STAT1001-2021-YT-1-CC1 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1001-2021-YT-1-QT1 (Responses).xlsx'
# PATH_RTHI1 = '../data/2021/response/STAT1001-2021-KT-2-THI1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rqt1 = util.parse_response(PATH_RQT1)
# rthi1 = util.parse_response(PATH_RTHI1)


#fix


rcc1['course_id'] = 'STAT1001-2021-YT-1'
rqt1['course_id'] = 'STAT1001-2021-YT-1'
# rthi1['course_id'] = 'STAT1001-2021-KT-2'


cc1 = mh.get_mark(rcc1, cutpoint, total=35, exam_id='STAT1001-2021-YT-1-CC1')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1001-2021-YT-1-QT1')
# thi1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='STAT1001-2021-YT-1-THI1')

res = (
    res
    .append(cc1)
    .append(qt1)
    # .append(thi1)
    )
# Out:
# /tmp/ipykernel_4682/605477757.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/605477757.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)

# %%
PATH_RCC1 = '../data/2021/response/INFO1001-2021-YVD-1-CC1 (Responses).xlsx'
PATH_RCC2 = '../data/2021/response/INFO1001-2021-YVD-1-CC2 (Responses).xlsx'
PATH_RCC3 = '../data/2021/response/INFO1001-2021-YVD-1-CC3 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/INFO1001-2021-YVD-1-QT1 (Responses).xlsx'
PATH_RTHILT1 = '../data/2021/response/INFO1001-2021-YVD-1-THILT1 (Responses).xlsx'
PATH_RTHITH1 = '../data/2021/response/INFO1001-2021-YVD-1-THITH1 (Responses).xlsx'


rcc1 = util.parse_response(PATH_RCC1)
rcc2 = util.parse_response(PATH_RCC2)
rcc3 = util.parse_response(PATH_RCC3)
rqt1 = util.parse_response(PATH_RQT1)
rthilt1 = util.parse_response(PATH_RTHILT1)
rthith1 = util.parse_response(PATH_RTHITH1)


# Fix

rcc1['course_id'] = 'INFO1001-2021-YVD-1'
rcc2['course_id'] = 'INFO1001-2021-YVD-1'
rcc3['course_id'] = 'INFO1001-2021-YVD-1'
rqt1['course_id'] = 'INFO1001-2021-YVD-1'
rthilt1['course_id'] = 'INFO1001-2021-YVD-1'
rthith1['course_id'] = 'INFO1001-2021-YVD-1'

cc1 = mh.get_mark(rcc1, cutpoint, total=15, exam_id='INFO1001-2021-YVD-1-CC1')
cc2 = mh.get_mark(rcc2, cutpoint, total=10, exam_id='INFO1001-2021-YVD-1-CC2')
cc3 = mh.get_mark(rcc3, cutpoint, total=20, exam_id='INFO1001-2021-YVD-1-CC3')
qt1 = mh.get_mark(rqt1, cutpoint, total=30, exam_id='INFO1001-2021-YVD-1-QT1')
thilt1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='INFO1001-2021-YVD-1-THILT1')
thith1 = mh.get_mark(rthith1, cutpoint, total=25, exam_id='INFO1001-2021-YVD-1-THITH1')



res = (
    res
    .append(cc1)
    .append(cc2)
    .append(cc3)
    .append(qt1)
    .append(thilt1)
    .append(thith1)
)

# Sai lop
res.loc[(res['course_id'] == "INFO1001-2021-YVD-1") & (res['class_id'] != "YVD-2021"), 'class_id'] = 'YVD-2021'
# Out:
# /tmp/ipykernel_4682/2346628825.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/2346628825.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc2)
# /tmp/ipykernel_4682/2346628825.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc3)
# /tmp/ipykernel_4682/2346628825.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)
# /tmp/ipykernel_4682/2346628825.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(thilt1)
# ...

# %%
PATH_RCC1 = '../data/2021/response/STAT1002-2021-DD-1-CC1 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1002-2021-DD-1-QT1 (Responses).xlsx'
# PATH_RTHI1 = '../data/2021/response/STAT1002-2021-DD-1-THI1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rqt1 = util.parse_response(PATH_RQT1)
# rthi1 = util.parse_response(PATH_RTHI1)


#fix


rcc1['course_id'] = 'STAT1002-2021-DD-1'
rqt1['course_id'] = 'STAT1002-2021-DD-1'
# rthi1['course_id'] = 'STAT1002-2021-DD-1'


cc1 = mh.get_mark(rcc1, cutpoint, total=25, exam_id='STAT1002-2021-DD-1-CC1')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1002-2021-DD-1-QT1')
# thi1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='STAT1002-2021-DD-1-THI1')

res = (
    res
    .append(cc1)
    .append(qt1)
    # .append(thi1)
    )
# Out:
# /tmp/ipykernel_4682/2218310115.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/2218310115.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)

# %%
PATH_RCC1 = '../data/2021/response/STAT1002-2021-DHD-1-CC1 (Responses).xlsx'
PATH_RQT1 = '../data/2021/response/STAT1002-2021-DHD-1-QT1 (Responses).xlsx'
# PATH_RTHI1 = '../data/2021/response/STAT1002-2021-DHD-1-THI1 (Responses).xlsx'

rcc1 = util.parse_response(PATH_RCC1)
rqt1 = util.parse_response(PATH_RQT1)
# rthi1 = util.parse_response(PATH_RTHI1)


#fix
rqt1.loc[rqt1.user_id == '2154010014', 'user_id'] = '2154010013'  # hoang le ngoc han, sai mssv


rcc1['course_id'] = 'STAT1002-2021-DHD-1'
rqt1['course_id'] = 'STAT1002-2021-DHD-1'
# rthi1['course_id'] = 'STAT1002-2021-DHD-1'


cc1 = mh.get_mark(rcc1, cutpoint, total=25, exam_id='STAT1002-2021-DHD-1-CC1')
qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1002-2021-DHD-1-QT1')
# thi1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='STAT1002-2021-DHD-1-THI1')

res = (
    res
    .append(cc1)
    .append(qt1)
    # .append(thi1)
    )
# Out:
# /tmp/ipykernel_4682/2420605847.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(cc1)
# /tmp/ipykernel_4682/2420605847.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   .append(qt1)

# %%
# PATH_RCC1 = '../data/2021/response/STAT1002-2021-XN-1-CC1 (Responses).xlsx'
# PATH_RQT1 = '../data/2021/response/STAT1002-2021-XN-1-QT1 (Responses).xlsx'
# # PATH_RTHI1 = '../data/2021/response/STAT1002-2021-XN-1-THI1 (Responses).xlsx'

# rcc1 = util.parse_response(PATH_RCC1)
# rqt1 = util.parse_response(PATH_RQT1)
# # rthi1 = util.parse_response(PATH_RTHI1)


# #fix


# rcc1['course_id'] = 'STAT1002-2021-XN-1'
# rqt1['course_id'] = 'STAT1002-2021-XN-1'
# # rthi1['course_id'] = 'STAT1001-2021-XN-2'


# cc1 = mh.get_mark(rcc1, cutpoint, total=25, exam_id='STAT1002-2021-XN-1-CC1')
# qt1 = mh.get_mark(rqt1, cutpoint, total=20, exam_id='STAT1002-2021-XN-1-QT1')
# # thi1 = mh.get_mark(rthilt1, cutpoint, total=50, exam_id='STAT1002-2021-XN-1-THI1')

# res = (
#     res
#     .append(cc1)
#     .append(qt1)
#     # .append(thi1)
#     )

# %%
# res
res.query('user_id == "2154010013"')
# res.query('name == "TRẦN ÁNH NGỌC"')
# res.query('course_id == "STAT1002-2021-DHD-1"')
# res.query('course_id == "STAT1001-2021-YT-1" and class_id != "YT-2021"')
# res.loc[(res['course_id'] == "INFO1001-2021-YVD-1") & (res['class_id'] != "YVD-2021"), 'class_id'] = 'YVD-2021'
# res.query('exam_id == "STAT1001-2021-KT-2-THI1"')
# res.query('exam_id == "INFO1001-2021-DD-1-CC3" and user_id == "215301014"')
# res.query('course_id == "STAT1001-2021-KX-2" and exam_id == "STAT1001-2021-KX-2-CC2"')
# res.query('course_id == "INFO1001-2021-DD-1" and class_id == "dd-2020"')
# res.query('exam_id == "INFO1001-2021-DHD-1-THITH1"')
# rcc2
# Out:
#        user_id  class_id            course_id                     exam_id  \
# 21  2154010013  DHD-2021  INFO1001-2021-DHD-1     INFO1001-2021-DHD-1-CC1
# 43  2154010013  DHD-2021  INFO1001-2021-DHD-1     INFO1001-2021-DHD-1-CC2
# 9   2154010013  DHD-2021  INFO1001-2021-DHD-1     INFO1001-2021-DHD-1-CC3
# 21  2154010013  DHD-2021  INFO1001-2021-DHD-1     INFO1001-2021-DHD-1-QT1
# 14  2154010013  DHD-2021  INFO1001-2021-DHD-1  INFO1001-2021-DHD-1-THILT1
# 15  2154010013  DHD-2021  INFO1001-2021-DHD-1  INFO1001-2021-DHD-1-THITH1
# 26  2154010013  DHD-2021  STAT1002-2021-DHD-1     STAT1002-2021-DHD-1-CC1
# 8   2154010013  DHD-2021  STAT1002-2021-DHD-1     STAT1002-2021-DHD-1-QT1
#
#     mark
# 21   9.5
# 43  10.0
# 9    9.0
# 21   5.0
# 14   6.0
# 15   5.0
# 26  10.0
# 8   10.0

# %%
# current_date = pd.Timestamp.now().date().__str__()
res.to_csv(f'../data/2021/response/all-response.csv', index=False)
res.to_parquet(f'../data/2021/response/all-response.parquet', index=False)
